# %%
import requests
import os
import json

bearer_token = "AAAAAAAAAAAAAAAAAAAAALQXewEAAAAADUo4zycsQlVjwmQiKF0%2B9QC15lw%3DulZaTfUawQxag70kFugTwfTnp42R2AkJNWFl3igGAzFvm4Eb4I"


def create_url():
    return "https://api.twitter.com/2/tweets/sample/stream"


def bearer_oauth(r):
    """
    Method required by bearer token authentication.
    """

    r.headers["Authorization"] = f"Bearer {bearer_token}"
    r.headers["User-Agent"] = "v2SampledStreamPython"
    return r


def connect_to_endpoint(url):
    response = requests.request("GET", url, auth=bearer_oauth, stream=True)
    print(response.status_code)
    for response_line in response.iter_lines():
        if response_line:
            json_response = json.loads(response_line)
            print(json.dumps(json_response, indent=4, sort_keys=True))
    if response.status_code != 200:
        raise Exception(
            "Request returned an error: {} {}".format(
                response.status_code, response.text
            )
        )


def main():
    url = create_url()
    timeout = 0
    while True:
        connect_to_endpoint(url)
        timeout += 1


if __name__ == "__main__":
    main()
# Out:
# 200
# {
#     "data": {
#         "id": "1547105281796034560",
#         "text": "@sardesairajdeep @zoo_bear How I consider it's wrongful arrest how can u say r u involved"
#     }
# }
# {
#     "data": {
#         "id": "1547105281808601089",
#         "text": "RT @backtolife_2023: The World Economic Forum Vows to Buy Up Dutch Farmers\u2019 Lands https://t.co/BNKXfe0wUK via @realnewspunch"
#     }
# }
# {
#     "data": {
#         "id": "1547105281808941056",
#         "text": "#\u092a\u0942\u0930\u094d\u0923\u0917\u0941\u0930\u0941_\u0938\u0902\u0924\u0930\u093e\u092e\u092a\u093e\u0932\u091c\u0940_\u092e\u0939\u093e\u0930\u093e\u091c\n\u091c\u094b \u092a\u0942\u0930\u094d\u0923 \u0938\u0924\u0917\u0941\u0930\u0941 \u0939\u094b\u0917\u093e \u0909\u0938\u092e\u0947\u0902 \u091a\u093e\u0930 \u092e\u0941\u0916\u094d\u092f \u0917\u0941\u0923 \u0939\u094b\u0924\u0947 \u0939\u0948\u0902:-\n\u0917\u0941\u0930\u0942 \u0915\u0947 \u0932\u0915\u094d\u0937\u0923 \u091a\u093e\u0930 \u092c\u0916\u093e\u0928\u093e, \u092a\u094d\u0930\u0925\u092e \u0935\u0947\u0926 \u0936\u093e\u0938\u094d\u0924\u094d\u0930 \u0915\u094b \u091c\u094d\u091e\u093e\u0928\u093e (\u091c\u094d\u091e\u093e\u0924\u093e)\u0964\n\u0926\u0942\u091c\u0947 \u0939\u0930\u093f \u092d\u0915\u094d\u0924\u093f \u092e\u0928 \u0915\u0930\u094d\u092e \u092c\u093e\u0928\u0940, \u0924\u0940\u0938\u0930\u0947 \u0938\u092e\u0926\u0943\u0937\u094d\u091f\u093f \u0915\u0930 \u091c\u093e\u0928\u0940\u0964\n\u091a\u094c\u0925\u0947 \u0935\u0947\u0926 \u0935\u093f\u0927\u093f \u0938\u092c \u0915\u0930\u094d\u092e\u093e, \u092f\u0939 \u091a\u093e\u0930 \u0917\u0941\u0930\u0941 \u0917\u0941\u0923 \u091c\u093e\u0928\u094b \u092e\u0930\u094d\u092e\u093e\u0964 #GuruPurnima https://t.co/M85vKpnrzX"
#     }
# }
# {
#     "data": {
#         "id": "1547105281770786816",
#         "text": "RT @TarotYouuuu: \u0e2b\u0e49\u0e32\u0e21\u0e02\u0e32\u0e22\u0e40\u0e2b\u0e25\u0e49\u0e32 \u0e41\u0e15\u0e48\u0e02\u0e32\u0e22\u0e01\u0e31\u0e0d\u0e0a\u0e32\u0e44\u0e14\u0e49 \u0e2d\u0e35\u0e2a\u0e31\u0e2a\u0e40\u0e21\u0e37\u0e2d\u0e07\u0e1e\u0e38\u0e17\u0e18\u0e0a\u0e34\u0e1a\u0e2b\u0e32\u0e22 \u0e01\u0e39\u0e40\u0e27\u0e17\u0e17\u0e17\u0e17\u0e17\u0e17\u0e17!!!!!! https://t.co/aFtRqQC9QU"
#     }
# }
# {
#     "data": {
#         "id": "1547105281770930177",
#         "text": "\u201cVeresiye \u00f6lm\u00fc\u015ft\u00fcr. Ba\u015f\u0131n\u0131z sa\u011f olsun\u201d https://t.co/lMdbLqLlk0"
#     }
# }
# {
#     "data": {
#         "id": "1547105281808539648",
#         "text": "RT @sof1azara03: $50 or 700rb Giveaway || 4 hrs \ud83c\udf4e\n\nRT + Follow @MrTastycalls"
#     }
# }
# {
#     "data": {
#         "id": "1547105281804468225",
#         "text": "RT @PornaholicXXX: Married construction worker pounds a naughty slut.\n\n https://t.co/NM1WRZkVgO"
#     }
# }
# {
#     "data": {
#         "id": "1547105281787953153",
#         "text": "RT @selubae94: @xlqspe22_ \u0e43\u0e0a\u0e48\u0e04\u0e48\u0e32 \u0e1e\u0e35\u0e48\u0e08\u0e38\u0e19\u0e40\u0e1b\u0e47\u0e19\u0e04\u0e19\u0e41\u0e23\u0e01\u0e02\u0e2d\u0e07\u0e41\u0e1a\u0e23\u0e19\u0e14\u0e4c\u0e17\u0e35\u0e48\u0e44\u0e14\u0e49\u0e40\u0e1b\u0e47\u0e19 Brand Ambassador"
#     }
# }
# {
#     "data": {
#         "id": "1547105281779580929",
#         "text": "74FCEDDC :\u53c2\u6226ID\n\u53c2\u52a0\u8005\u52df\u96c6\uff01\nLv120 \u30a2\u30c8\u30a5\u30e0\nhttps://t.co/itSa991Rp4"
#     }
# }
# {
#     "data": {
#         "id": "1547105281800224769",
#         "text": "@Rupa_Hwarang_ \ubc30\ucf70\ub791\ub2d8\ub3c4 \uc88b\uc740 \ud558\ub8e8 \ubcf4\ub0b4\uace0 \uacc4\uc2e0\uac00\uc694?"
#     }
# }
# {
#     "data": {
#         "id": "1547105281774997506",
#         "text": "RT @Simp4Sluts: what the hell did Jehovah even witness"
#     }
# }
# {
#     "data": {
#         "id": "1547105281791893504",
#         "text": "RT @fehgalvao_: 2B \ud83d\udda4\ud83e\udd0d\ud83d\udda4 Nier Automata https://t.co/mA9wmVtBEj"
#     }
# }
# {
#     "data": {
#         "id": "1547105281808769025",
#         "text": "RT @Harley_Tory: An MP who ordered his MPs to support an MP who sexually touched a teen boy with sexual intent intent.\nPass it on if you th\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1547105281783611393",
#         "text": "@mihletshemese Yupppp!"
#     }
# }
# {
#     "data": {
#         "id": "1547105281791893505",
#         "text": "https://t.co/12vo5375FN"
#     }
# }
# {
#     "data": {
#         "id": "1547105281804447745",
#         "text": "RT @fernseelee: \u0e2a\u0e21\u0e31\u0e22\u0e40\u0e2d\u0e2a\u0e40\u0e08\u0e21\u0e32\u0e44\u0e17\u0e22\u0e43\u0e2b\u0e21\u0e48\u0e46 \u0e19\u0e32\u0e07\u0e04\u0e25\u0e31\u0e48\u0e07\u0e40\u0e1a\u0e40\u0e1a\u0e49\u0e01\u0e31\u0e19\u0e21\u0e32\u0e01 \u0e41\u0e22\u0e48\u0e07\u0e01\u0e31\u0e19\u0e08\u0e35\u0e1a\u0e2a\u0e38\u0e14\u0e24\u0e17\u0e18\u0e34\u0e4c \u0e19\u0e35\u0e48\u0e22\u0e31\u0e07\u0e19\u0e36\u0e01\u0e2d\u0e22\u0e39\u0e48\u0e40\u0e25\u0e22\u0e27\u0e48\u0e32\u0e16\u0e49\u0e32\u0e40\u0e1b\u0e47\u0e19\u0e44\u0e2d\u0e14\u0e2d\u0e25\u0e2a\u0e21\u0e31\u0e22\u0e19\u0e35\u0e49\u0e04\u0e07\u0e21\u0e35\u0e14\u0e23\u0e32\u0e21\u0e48\u0e32\u0e44\u0e1b\u0e41\u0e25\u0e49\u0e27 \u0e41\u0e15\u0e48\u0e1e\u0e2d\u0e40\u0e1b\u0e47\u0e19\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1547105281770930176",
#         "text": "RT @gulfonly97: IGS : bester_besecret  - 13/07/22\n\ud83d\udd87 https://t.co/XRWGkcUM2e     \n#GULFXTBMonogram \n\nGULF KANAWUT\n@gulfkanawut\n#\u0e01\u0e25\u0e31\u0e1f\u0e04\u0e13\u0e32\u0e27\u0e38\u0e12\u0e34\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1547105281783386113",
#         "text": "RT @proxcinemente: Paralelismos. #BetterCallSaul #BreakingBad https://t.co/lDxYglQziN"
#     }
# }
# {
#     "data": {
#         "id": "1547105281783521280",
#         "text": "RT @javerias: \u0645\u062c\u06be\u06d2 \u06cc\u06c1 \u0633\u0645\u062c\u06be \u0646\u06c1\u06cc\u06ba \u0622\u0631\u06c1\u06cc \u0627\u0631\u0634\u062f \u0634\u0631\u06cc\u0641 \u0646\u06d2 \u06a9\u06cc\u0627 \u06a9\u06cc\u0627 \u06c1\u06d2 \u061f\n\u06a9\u0628\u06be\u06cc \u06a9\u0631\u067e\u0634\u0646 \u0646\u06c1\u06cc\u06ba \u06a9\u06cc \n\u06a9\u0628\u06be\u06cc \u06a9\u0648\u0626\u06cc \u0630\u0627\u062a\u06cc \u0645\u0627\u0644\u06cc\u0627\u062a\u06cc \u0646\u062c\u06cc \u0641\u0627\u0626\u062f\u06c1 \u0646\u06c1\u06cc\u06ba \u0644\u06cc\u0627 \n\u062f\u0631\u0648\u06cc\u0634 \u0628\u0646\u062f\u06c1 \u06c1\u06d2\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1547105281771028480",
#         "text": "RT @philimonTv: I talked to 5 parents who raised highly successful adults\u2014here are 4 things they never did when their kids were young"
#     }
# }
# {
#     "data": {
#         "id": "1547105281796059137",
#         "text": "@studywithawan MasyaAllah so pretty!!!\ud83d\ude3b\u2764\ufe0f"
#     }
# }
# {
#     "data": {
#         "id": "1547105281804476416",
#         "text": "RT @SahibePetek: Ayak show , benim g\u00fczel arkada\u015flar\u0131m \ud83d\udd25 #Kocaeli #Tatil https://t.co/jLLpopTkWj"
#     }
# }
# {
#     "data": {
#         "id": "1547105281796182024",
#         "text": "The rising cost of living is hitting muticultural communities hard. These groups are trying to\u00a0help https://t.co/nnfsqwKFkg"
#     }
# }
# {
#     "data": {
#         "id": "1547105281796087809",
#         "text": "RT @JackPosobiec: Did John Bolton realize he just publicly admitted the US does coups around the world - like Putin has been saying all alo\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1547105281800536065",
#         "text": "RT @yuki_u_tan: @ikuinaakiko1917 \u306a\u3044\u308f\u30fc\u3002"
#     }
# }
# {
#     "data": {
#         "id": "1547105281795969024",
#         "text": "@plaaatipuss jelas la \ud83d\ude2d"
#     }
# }
# {
#     "data": {
#         "id": "1547105281783521281",
#         "text": "@NanyFrail02 @Oleg_Ilchenko \u041d\u0435 \u0442\u043e \u0441\u043b\u043e\u0432\u043e\ud83e\udd23\ud83e\udd23\ud83e\udd23"
#     }
# }
# {
#     "data": {
#         "id": "1547105281804587008",
#         "text": "RT @Abeba1Abeba: \ud83d\udc8a\ud83d\udc92\u1260\u1235\u1218 \u12a3\u1265 ;\u12c8\u12c8\u120d\u12f5 \u12c8\u1218\u1295\u1348\u1235 \u1245\u12f1\u1235 \u12a3\u1213\u12f1 \u12a3\u121d\u120b\u12ad \u12a3\u121c\u1295 \u1230\u120b\u121d\u12a9\u121d \u12ed\u1265\u12db\u1215 \u12f0\u1242 \u1270\u12cb\u1205\u12f6 \u1270\u130b\u1229 \u12a3\u1215\u12cb\u1270\u12ed \u1295\u12d1 \u1213\u1262\u122d\u1293 \u1295\u12d8\u121d\u122d \u12a8\u121d\u12a1 \u12f5\u121b \u1290\u1272 \u12cd\u1341\u12d5 \u1205\u12dd\u1265\u1293 \u12f5\u121d\u1342 \u1295\u12a9\u1295 \u12dd\u1270\u1263\u1228\u12a8 \u1309\u1263\u12a4 \u12ed\u130d\u1260\u1228\u120d\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1547105281796059139",
#         "text": "RT @missufe: $50 | 700K in 2 Hours \ud83e\udd84\n\n- RT &amp; Follow @Coach_Khaled0 + like 3 last tweet"
#     }
# }
# {
#     "data": {
#         "id": "1547105281779408896",
#         "text": "RT @saturight_: Yo seria igual o incluso peor si me lo encuentro a jeff. Lo m\u00e1s seguro es que termino desmayada al final \n https://t.co/TM8\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1547105281796177921",
#         "text": "RT @spicymarii: island garllll https://t.co/J3RIujsSXo"
#     }
# }
# {
#     "data": {
#         "id": "1547105281791778816",
#         "text": "@BABE3XVI \u0e21\u0e2d\u0e19\u0e34\u0e48\u0e07\u0e04\u0e48\u0e30"
#     }
# }
# {
#     "data": {
#         "id": "1547105281770983426",
#         "text": "Up.. cleaned the kitchen, and living room, washed everything down, now preparing to paint. I love how my work flow is\u2026 thank you Chuck for Deep Work\u2026 @hammerchucks it changed my whole process on how to get shit done."
#     }
# }
# {
#     "data": {
#         "id": "1547105281787670528",
#         "text": "RT @Tajinder29: Info\n\n    #HappyBirthdayAsimRiaz"
#     }
# }
# {
#     "data": {
#         "id": "1547105281796370432",
#         "text": "\u4eca\u65e5\u306f\u3044\u3063\u3071\u3044\u3057\u3083\u3076\u3057\u3083\u3076\u3059\u308b\u305e\u301c\ud83d\ude0d\u3048\u3061\ud83c\udf3a\u52d5\u753b\u3060\u30fc\u3044\u3057\u3085\u304d\ud83c\udf38\u5927\u4eba\u306e\u95a2\u4fc2 \u306b\u306a\u3063\u3066\u307b\u3057\u3044\u306e\ud83e\udd94\u30d7\u30ed\u30d5\u30a3\u30fc\u30eb\u307f\u3066\u306d\ud83d\udc96"
#     }
# }
# {
#     "data": {
#         "id": "1547105281775046662",
#         "text": "RT @DaFoxile: $20 [ 1 winner ] 2 hrs\n\n\ud83d\udca5RT &amp;  Follow: @ChiniCrypto \n\n\ud83d\udca5RT &amp; like their pin \ud83d\udccc"
#     }
# }
# {
#     "data": {
#         "id": "1547105281779195904",
#         "text": "@_Erika_Em7_ \u30ef\u30f3\u30c1\u30fc\u30e0\u3060\u304b\u3089\u3000\u3044\u3044\u30c1\u30fc\u30e0\u3060\u306d\ud83e\udd17\u3002\ud83c\udf34\ud83d\ude03\ud83d\udc95"
#     }
# }
# {
#     "data": {
#         "id": "1547105281787985920",
#         "text": "cute naman ng golden retriever na yan\ud83e\udd2d\ud83e\udd2d https://t.co/Ptzu6MtjtZ"
#     }
# }
# {
#     "data": {
#         "id": "1547105281779310592",
#         "text": "\u0411\u044b\u0432\u0430\u0435\u0442. \nhttps://t.co/FfrRXg5k7h"
#     }
# }
# {
#     "data": {
#         "id": "1547105281804738560",
#         "text": "RT @tiantianxs321: \u7c89\u4e1d\u6295\u7a3f\ud83e\uddda\u200d\u2642\ufe0f\n\u4e09\u4e9a\u6781\u54c1\u5973\u795e\u5b8c\u7f8e\u8eab\u6750\uff0c\u5916\u51fa\u966a\u91d1\u4e3b\u7238\u7238\u65c5\u6e38\uff0c\u5e8a\u4e0a\u9a9a\u5f97\u5f88\uff0c\u5916\u4eba\u773c\u91cc\u7684\u5973\u795e\uff0c\u5176\u5b9e\u662f\u4e2a\u559c\u6b22\u88ab\u5185\u5c04\u7684\u7cbe\u6db2\u5bb9\u5668\uff0c\u6781\u54c1\u4e2d\u7684\u6781\u54c1\uff0c\u6700\u7f8e\u53cd\u5dee\uff0c\u7167\u7247p16 \u89c6\u989112 \u5b8c\u6574\u7248\u4e3b\u9875\u79c1\u4fe1\u63d0\u53d6 https://t.co/TjuxbS7o5H"
#     }
# }
# {
#     "data": {
#         "id": "1547105285986287619",
#         "text": "RT @vanglockkk: a famosa nicortina https://t.co/3yMy4jxTmE"
#     }
# }
# {
#     "data": {
#         "id": "1547105285990338562",
#         "text": "RT @democrazymedia: Ayah Brigadir Joshua Ungkap Kejanggalan: Anak Saya Sniper Handal, Agak Mustahil Jarak 7 Meter Bisa Meleset\nhttps://t.co\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1547105285981908994",
#         "text": "RT @sssilkk: \u0e40\u0e18\u0e23\u0e14\u0e23\u0e27\u0e21\u0e0b\u0e35\u0e23\u0e35\u0e48\u0e22\u0e4c\u0e2a\u0e2d\u0e1a\u0e2a\u0e27\u0e19 \u0e2a\u0e37\u0e1a\u0e04\u0e14\u0e35 \u0e44\u0e27\u0e49\u0e14\u0e39\u0e27\u0e31\u0e19\u0e2b\u0e22\u0e38\u0e14\u0e43\u0e2b\u0e49\u0e15\u0e32\u0e41\u0e09\u0e30\ud83d\udd0d \u0e04\u0e31\u0e14\u0e21\u0e32\u0e41\u0e25\u0e49\u0e27\u0e2a\u0e19\u0e38\u0e01\u0e17\u0e38\u0e01\u0e40\u0e23\u0e37\u0e48\u0e2d\u0e07\ud83d\udc40 https://t.co/8MPX6c6uv3"
#     }
# }
# {
#     "data": {
#         "id": "1547105285981868033",
#         "text": "RT @kagekisexygazo7: \u30de\u30ab\u30ed\u30f3\u3082\u624b\u4f5c\u308a\u51fa\u6765\u3061\u3083\u3046\u25cf\u25cf\u9858\u671b\u30a2\u30ea\u306e\u30c9M\u3061\u3083\u3093\u304c\u767b\u5834\n\n\u3053\u306e\u4f5c\u54c1\u306b\u306f\u4f55\u5ea6\u304a\u4e16\u8a71\u306b\u306a\u3063\u305f\u304b\u3089\u308f\u304b\u3089\u3093\uff57 \nhttps://t.co/wncRzYjb3v"
#     }
# }
# {
#     "data": {
#         "id": "1547105285994692608",
#         "text": "@Teatlemania Now, THAT\u2019S a look \ud83d\udc4d\ud83c\udffb\ud83e\uded6"
#     }
# }
# {
#     "data": {
#         "id": "1547105285990486016",
#         "text": "@TrullaCouch @schwarzbuch_k Im Flur ja \u201eganz normal\u201c."
#     }
# }
# {
#     "data": {
#         "id": "1547105285994516480",
#         "text": "RT @AnujBajpai_: \u092e\u0948\u0902\u0928\u0947 \u0905\u092a\u0928\u0947 \u091c\u0940\u0935\u0928 \u092e\u0947\u0902 \u092f\u0926\u093f \u0938\u092c\u0938\u0947 \u091c\u094d\u092f\u093e\u0926\u093e \u0915\u093f\u0938\u0940 \u0938\u0947 \u0915\u0941\u091b \u0938\u0940\u0916\u093e \u0939\u0948 \u0924\u094b \u0935\u0939 \u0939\u0948 \u0936\u094d\u0930\u0940\u092e\u0926\u094d\u092d\u0917\u0935\u0926\u094d\u0917\u0940\u0924\u093e \u0936\u094d\u0930\u0940 \u0930\u093e\u092e\u093e\u092f\u0923 \u0914\u0930 \u092a\u093f\u0924\u093e \u0938\u0947\n\u0905\u0930\u094d\u0925\u093e\u0924 \u0928\u093f\u0938\u094d\u0935\u093e\u0930\u094d\u0925\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1547105285986205697",
#         "text": "RT @RedCollectiveUK: This \ud83d\udc47\ud83c\udffc is the real reason Starmer is desperately slithering around, like a slippery snake in the mud, seeking a GE. H\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1547105285978071045",
#         "text": "RT @Emily0603: \u6700\u8fd1\u3053\u306e\u30a2\u30e9\u30b9\u30ab\u3067\u718a\u304c\u30b7\u30e3\u30b1\u3092\u3068\u3063\u3066\u98df\u3079\u308b\u30e9\u30a4\u30d6\u30ab\u30e1\u30e9\u3088\u304f\u898b\u3066\u308b\u3093\u3060\u3051\u3069\u3001\u4eca\u65e5\u3081\u3063\u3061\u3083\u718a\u3044\u308b\nhttps://t.co/w8EUVboPHq https://t.co/668ps0UpVk"
#     }
# }
# {
#     "data": {
#         "id": "1547105285990666241",
#         "text": "@PotterPuffer Lewat"
#     }
# }
# {
#     "data": {
#         "id": "1547105285965336577",
#         "text": "RT @Angham_Media: \u0645\u0646 \u063a\u0631\u0627\u0645 \u0627\u0644\u0634\u0648\u0642 \u062c\u0648\u0627\u0646\u0627 \u0646\u0633\u064a\u0646\u0627 \u0645\u064a\u0646 \u0633\u0647\u0631\u0627\u0646 \u0648\u064a\u0627\u0646\u0627 \u2764\ufe0f https://t.co/BppF3SP2PD"
#     }
# }
# {
#     "data": {
#         "id": "1547105285973905408",
#         "text": "RT @uourhope: EXCUSE ME?!?!?!? https://t.co/47w55x59b3"
#     }
# }
# {
#     "data": {
#         "id": "1547105285977673728",
#         "text": "@TL_Techy @techswami_yt You said you will buy that\ud83d\ude36"
#     }
# }
# {
#     "data": {
#         "id": "1547105285965168640",
#         "text": "90\u9023\u3059\u308a\u629c\u3051\u305a1\u51f8\u3067\u304d\u305f\u3041\u3041\uff01\uff01\uff01\n\u3046\u308c\u3057\u3044\u3044\ud83e\udd79\ud83e\udd79 https://t.co/8VEqoIlx8V"
#     }
# }
# {
#     "data": {
#         "id": "1547105285990658048",
#         "text": "RT @wje_520: \u0e40\u0e19\u0e35\u0e22\u0e19\u0e44\u0e21\u0e48\u0e44\u0e2b\u0e27 55555555555555555 \u0e1e\u0e27\u0e01\u0e40\u0e23\u0e32\u0e04\u0e19\u0e44\u0e17\u0e22\u0e17\u0e33\u0e1a\u0e38\u0e0d\u0e15\u0e31\u0e01\u0e1a\u0e32\u0e15\u0e23\u0e23\u0e48\u0e27\u0e21\u0e01\u0e31\u0e19\u0e01\u0e31\u0e1a\u0e1e\u0e35\u0e48\u0e41\u0e08\u0e47\u0e04 555555555555555555 https://t.co/PmxGjOt0jU"
#     }
# }
# {
#     "data": {
#         "id": "1547105285998874624",
#         "text": "RT @PTIofficial: Shukriya Bhakkar!! \n#VoteOnJuly17 https://t.co/ArgLtPRI0c"
#     }
# }
# {
#     "data": {
#         "id": "1547105285999050752",
#         "text": "@shuntroise makasih ann!! smoga gacha kamu wangy wangyy"
#     }
# }
# {
#     "data": {
#         "id": "1547105286003036161",
#         "text": "RT @MarcoRizzoPC: Solidariet\u00e0 ai rappresentanti dei #tassisti in lotta incatenati davanti a Palazzo Chigi. Draghi se ne deve andare! https:\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1547105285978095616",
#         "text": "RT @Futbol10gs: \ud83d\udca5Galatasaray, yerli rotasyonunu g\u00fc\u00e7lendirmek i\u00e7in Kaan Ayhan\u2019da karar k\u0131ld\u0131..Sar\u0131 k\u0131rm\u0131z\u0131l\u0131lar Sassuolo Kul\u00fcb\u00fc ile yeniden\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1547105285999034368",
#         "text": "RT @Viviennewonder: \u0e21\u0e32\u0e04\u0e23\u0e31\u0e1a \u0e21\u0e32\u0e41\u0e08\u0e01\u0e01\u0e31\u0e19\u0e2b\u0e19\u0e48\u0e2d\u0e22 2 \u0e01\u0e25\u0e48\u0e2d\u0e07 \u0e01\u0e25\u0e48\u0e2d\u0e07\u0e25\u0e30 7000 \u0e1a\u0e32\u0e17\u0e44\u0e1b\u0e40\u0e25\u0e22 \u0e07\u0e48\u0e32\u0e22\u0e46 \u0e40\u0e2b\u0e21\u0e37\u0e2d\u0e19\u0e40\u0e14\u0e34\u0e21\u0e41\u0e04\u0e48 RT + FOLLOW \u0e1b\u0e23\u0e30\u0e01\u0e32\u0e28\u0e2d\u0e32\u0e17\u0e34\u0e15\u0e22\u0e4c\u0e2b\u0e19\u0e49\u0e32\u0e04\u0e23\u0e31\u0e1a https://t.co/T\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1547105285977690112",
#         "text": "RT @daradaily: \u0e2a\u0e48\u0e2d\u0e07 7 \u0e0b\u0e38\u0e1b\u0e15\u0e32\u0e23\u0e4c\u0e2b\u0e25\u0e48\u0e2d\u0e41\u0e2d\u0e1a\u0e40\u0e0a\u0e35\u0e22\u0e23\u0e4c\u0e41\u0e21\u0e17\u0e0a\u0e4c\u0e41\u0e21\u0e19\u0e22\u0e39-\u0e25\u0e34\u0e40\u0e27\u0e2d\u0e23\u0e4c\u0e1e\u0e39\u0e25\n\n\u0e2d\u0e48\u0e32\u0e19\u0e02\u0e48\u0e32\u0e27\u0e15\u0e48\u0e2d : https://t.co/mnlWkRCHhD\n\n#\u0e14\u0e32\u0e23\u0e32\u0e40\u0e14\u0e25\u0e35\u0e48 #daradaily #\u0e02\u0e48\u0e32\u0e27\u0e1a\u0e31\u0e19\u0e40\u0e17\u0e34\u0e07\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1547105285998878720",
#         "text": "RT @angelaeagle: Why he needs to go NOW"
#     }
# }
# {
#     "data": {
#         "id": "1547105285973676039",
#         "text": "@N1collit4 Pa reforzar la amistad"
#     }
# }
# {
#     "data": {
#         "id": "1547105285986287618",
#         "text": "- \u0627\u0644\u0648\u0642\u062a \u0645\u062c\u0627\u0646\u064a\u060c \u0644\u0643\u0646\u0647 \u0644\u0627 \u064a\u064f\u0642\u062f\u0631 \u0628\u062b\u0645\u0646. \u0644\u0627 \u064a\u0645\u0643\u0646\u0643 \u0627\u0645\u062a\u0644\u0627\u0643\u0647\u060c \u0648\u0644\u0643\u0646 \u064a\u0645\u0643\u0646\u0643 \u0627\u0633\u062a\u062e\u062f\u0627\u0645\u0647.\nm"
#     }
# }
# {
#     "data": {
#         "id": "1547105285986062337",
#         "text": "@choerryslvr me or al"
#     }
# }
# {
#     "data": {
#         "id": "1547105285990653952",
#         "text": "RT @vaience_com: \u3010\u5929\u4f53\u89b3\u6e2c\u3011\u4eca\u591c\u306e\u6708\u306f\u30b9\u30fc\u30d1\u30fc\u30e0\u30fc\u30f3\u30012022\u5e74\u3067\u6700\u3082\u5927\u304d\u306a\u6e80\u6708\n\nhttps://t.co/Ezk75fNVKp\n\u4eca\u65e513\u65e5\u591c\u304b\u308914\u65e5\u660e\u3051\u65b9\u306b\u898b\u3089\u308c\u308b\u6708\u306f\u3001\u4eca\u5e74\u898b\u3048\u308b\u6e80\u6708\u306e\u3046\u3061\u3067\u6700\u3082\u5927\u304d\u306a\u30b9\u30fc\u30d1\u30fc\u30e0\u30fc\u30f3\u3002\u4eca\u5e74\u6700\u3082\u9060\u304b\u3063\u305f\u6e80\u6708\u3068\u6bd4\u3079\u308b\u3068\u76f4\u5f84\u3067\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1547105285965094913",
#         "text": "RT @KBSnews: \uad11\uba85\uc5ed \uc9c0\ud558 \uc77c\ubd80 \uce68\uc218\u2026\u201c\uc5f4\ucc28 \uc9c0\uc5f0\uc740 \uc5c6\uc5b4\u201d #KBS #KBS\ub274\uc2a4\n\nhttps://t.co/fnumSl4qtg"
#     }
# }
# {
#     "data": {
#         "id": "1547105285969707008",
#         "text": "RT @kookv__1230m: \u3053\u306e\u6642\u3082\u9ad8\u6821\u306a\u3093\u3060\u305c\uff1f(\u91cd\u8981\u306a\u4e8b\u3060\u304b\u3089\u3057\u3064\u3053\u304f\u8a00\u3046) https://t.co/o2aG4yDruj"
#     }
# }
# {
#     "data": {
#         "id": "1547105285999071232",
#         "text": "RT @zenoloves: 24. https://t.co/4LQFAzfXE1"
#     }
# }
# {
#     "data": {
#         "id": "1547105285999054849",
#         "text": "RT @sushielovey: oversized shirts are so damn comfy to wear"
#     }
# }
# {
#     "data": {
#         "id": "1547105285965336576",
#         "text": "RT @TimRunsHisMouth: The question of if we should allow kids to go to drag queen events isn't the primary one...\n\nWe should first ask: Why\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1547105286002982912",
#         "text": "@inno6_mogotsi @EarlOfGC Ehe rra, nnyaa re a le utlwa\ud83e\udd23\ud83e\udd23"
#     }
# }
# {
#     "data": {
#         "id": "1547105285965156354",
#         "text": "@babuundead ga ngepull dulu deh, takut adeknya ikutan kena \ud83d\ude2d\ud83d\ude2d"
#     }
# }
# {
#     "data": {
#         "id": "1547105285965111297",
#         "text": "\uadf8\ub7ec\uae30 \uc804\uc5d0 \uc774\ubbf8 \uac78\ub7ec\uc9c8 \uc100\uae30\uac00 \u314b\u314b"
#     }
# }
# {
#     "data": {
#         "id": "1547105286003081226",
#         "text": "Hey I joined a network called Mnbllerewordsln and earned $25.00! You get paid for testing out new free apps and posting on social media. Sign up with my link for an instant $25 signup bonus! https://t.co/l2sFfLT8uB"
#     }
# }
# {
#     "data": {
#         "id": "1547105285990391809",
#         "text": "RT @SonXeno: LMFAOOOOOOOO https://t.co/heEdsMbzQo"
#     }
# }
# {
#     "data": {
#         "id": "1547105285986295809",
#         "text": "deobis who aren\u2019t also orbits are so annoying and unfunny"
#     }
# }
# {
#     "data": {
#         "id": "1547105286003228673",
#         "text": "RT @Fevirre: @thatdaffyduck We've come for your source https://t.co/johSm9W4vG"
#     }
# }
# {
#     "data": {
#         "id": "1547105290167808000",
#         "text": "@diwurengezhong1 @shipinbot"
#     }
# }
# {
#     "data": {
#         "id": "1547105290159419392",
#         "text": "\uc0ac\uadf9 \ucd94\ucc9c \ubc1b\uc744\uac8c\uc694 \ud83e\udd24"
#     }
# }
# {
#     "data": {
#         "id": "1547105290188890118",
#         "text": "@majolpl @osita_ Jajajajajajajaja necesito recordar ese cap\u00edtulo!! Ma\u00f1ana lo busco y lo vemos"
#     }
# }
# {
#     "data": {
#         "id": "1547105290163671041",
#         "text": "RT @WasiuddinSiddi1: \u0905\u092a\u0928\u0940 \u0916\u0942\u092c\u093f\u092f\u094b\u0902 \u092e\u0947\u0902 \u0907\u091c\u093c\u093e\u092b\u093c\u093e \u0915\u0930\u093f\u092f\u0947 \u0932\u094b\u0917 \u0906\u092a\u0915\u094b \u0906\u092a\u0915\u0940 \u0916\u0942\u092c\u093f\u092f\u094b\u0902 \u0915\u0940 \u0935\u091c\u0939 \u0938\u0947 \u0939\u0940 \u092a\u0938\u0928\u094d\u0926 \u0915\u0930\u0924\u0947 \u0939\u0948 \u0964"
#     }
# }
# {
#     "data": {
#         "id": "1547105290184757248",
#         "text": "RT @BarcaUniversal: The Barcelona board are now pushing for the signing of Robert Lewandowski. Key days are upcoming, and they feel confide\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1547105290171998209",
#         "text": "@boumkai good aftiee"
#     }
# }
# {
#     "data": {
#         "id": "1547105290168029185",
#         "text": "RT @colakrengin: T\u00dcRK M\u0130LLET\u0130N\u0130N MALI S\u0130T ALANI #MehmetCengiz buralarla ilgili anla\u015fmalar yapm\u0131\u015f HANG\u0130 C\u00dcRETLE? SEN K\u0130ME G\u00dcVENIYORSUN ? \nSe\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1547105290189176832",
#         "text": "RT @DJ_GIVEAWAY2: $50 | 4HRS \ud83d\ude80\n\n\u2705 Retweet + Follow @DJ_GIVEAWAY2 \ud83d\udd14\n\nReroll"
#     }
# }
# {
#     "data": {
#         "id": "1547105290159529985",
#         "text": "RT @1RealWang_1: Stop leaving kids at your shops, I just bought Lucozade the big one for 1.50p, Wo kwasia..."
#     }
# }
# {
#     "data": {
#         "id": "1547105290188890119",
#         "text": "RT @irishgooner247: Fill Jada with BBC https://t.co/PrXPUio4aU"
#     }
# }
# {
#     "data": {
#         "id": "1547105290189172736",
#         "text": "RT @kuro_chan814: \u30b3\u30ed\u30ca\u306e\u5897\u52a0\u304c\u3059\u3054\u3044\u3002\u4eca\u65e5\u691c\u67fb\u3057\u305f\u4eba\u305f\u3061\u304c\u3001\u307b\u307c\u967d\u6027\u8005\u3002\n\u4eca\u56de\u306e\u306f\u9ad8\u71b1\u306e\u60a3\u8005\u304c\u591a\u3044\u6c17\u304c\u3059\u308b\u3002\n\u307e\u305f\u3001\u30ad\u30c3\u30c8\u306e\u78ba\u4fdd\u3068\u304b\u3001\u691c\u67fb\u306a\u3069\u3067\u5fd9\u3057\u304f\u306a\u308a\u305d\u3046\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1547105290176581632",
#         "text": "@hina_yoruami \u672c\u5f53\u306b\u60aa\u5922\u898b\u308b\u3093\u3060\u306d\uff01\uff1f\n\u9006\u306b\u30b9\u30c8\u30ec\u30b9\u306a\u3063\u3061\u3083\u3044\u305d\u3046\ud83d\ude31"
#     }
# }
# {
#     "data": {
#         "id": "1547105290163998721",
#         "text": "I enjoy being h\n\n?\u061f\n\u0671\u0648\u0646\u0671\u0633 \u2066\u0671\u0646\u0671\u0633 \u0646\u0645\u0634\u06d2\nattention \u25e5\u2022\u064a\u0627\u0631\u0627\u2022 \ufea7\u0655\u0653\u0635\u064d\u0645\u064d\u2022\ufedc\u0655\u0648\u0650\u062f\u0653 https://t.co/AGZWXqjHHo"
#     }
# }
# {
#     "data": {
#         "id": "1547105290159460352",
#         "text": "RT @MrSinha_: Hello @UNHumanRights @UNGeneva, how much do you charge to tweet on such incidents? Does it fall under minority under attack c\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1547105290171998208",
#         "text": "RT @mizkan_official: \u300c\u30b7\u30e3\u30f3\u30d1\u30f3\u30b3\u30eb\u30af\u30b5\u30a6\u30f3\u30c9\u30d3\u30cd\u30ac\u30fc\u300d\u304c\u30c8\u30ec\u30f3\u30c9\u5165\u308a\u3057\u3066\u305f\u304b\u3089\u4f55\u304b\u3068\u601d\u3044\u304d\u3084\u3001\u3053\u306e\u5b50\u306e\u3053\u3068\u3067\u3059\u304b\uff1f https://t.co/RbuQ9l06Lk"
#     }
# }
# {
#     "data": {
#         "id": "1547105290172395520",
#         "text": "Laki ugh https://t.co/xZ0w4e42Qt"
#     }
# }
# {
#     "data": {
#         "id": "1547105290159636480",
#         "text": "RT @HWHJLOOKS: https://t.co/XYTqzj5VRW"
#     }
# }
# {
#     "data": {
#         "id": "1547105290176249856",
#         "text": "RT @seheaventeen: please choose a better event organizer in the Philippines next time @pledis_17 @pledis17_STAFF @pledisnews we anticipated\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1547105290167910403",
#         "text": "RT @Phil_Osophi: Look on the bright side, #Boris actually came out on a high, when it all goes to utter shit in the next year or two @Boris\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1547105290184667136",
#         "text": "RT @SummerElle_: RT if you love to be wild and free\n#onlyfans #onlyfansbabe #aussieonlyfans https://t.co/HPSfDrqNl2"
#     }
# }
# {
#     "data": {
#         "id": "1547105290197540864",
#         "text": "RT @_bdmonday: \u0e16\u0e49\u0e32\u0e44\u0e21\u0e48\u0e2b\u0e25\u0e38\u0e14\u0e40\u0e23\u0e17\u0e04\u0e32\u0e2a\u0e36\u0e2e\u0e30 + \u0e44\u0e14\u0e49\u0e40\u0e2e\u0e22\u0e4c\u0e42\u0e0b\u0e21\u0e32\u0e01\u0e01\u0e27\u0e48\u0e32 c3 \u0e01\u0e48\u0e2d\u0e19\u0e08\u0e1a\u0e41\u0e1e\u0e17\u0e0b\u0e4c \u0e41\u0e08\u0e01 100 \u0e04\u0e48\u0e32!! \n#GenshinImpactth https://t.co/94ygn417ZI"
#     }
# }
# {
#     "data": {
#         "id": "1547105290163695616",
#         "text": "RT @kypppb: \u0e41\u0e2b\u0e21 \u0e14\u0e2d\u0e01\u0e44\u0e21\u0e49\u0e14\u0e2d\u0e01\u0e43\u0e08 https://t.co/eN7hX9cCug"
#     }
# }
# {
#     "data": {
#         "id": "1547105290180517888",
#         "text": "@glxyminho I made his spiderweb skirt for fort worth. It took me so long to make"
#     }
# }
# {
#     "data": {
#         "id": "1547105290184802304",
#         "text": "RT @HYBE_MERCH: Are you going to stay in the box or not?\n\nj-hope 'Jack In The Box' Official Merch.\nConcept Photo\ud83d\udcf8 #1\n\n\ud83c\udf81Hope In The Box\n\ud83d\udccc \uc0c1\ud488\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1547105290171994112",
#         "text": "RT @HAGnews01: FOX\u65b0\u95fb\u91c7\u8bbf\u53f0\u6e7e\u6c11\u4f17\u5bf9\u4e2d\u5171\u5165\u4fb5\u7684\u6001\u5ea6\n\n\u201c\u8fd9\u662f\u6ca1\u6709\u610f\u4e49\u7684\uff0c\u5373\u4f7f\u6211\u5bb3\u6015\uff0c\u6211\u4eec\u751f\u6d3b\u5728\u8fd9\u7247\u571f\u5730\u4e0a\uff0c\u9664\u4e86\u53cd\u51fb\uff0c\u6211\u4eec\u4ec0\u4e48\u4e5f\u505a\u4e0d\u4e86\u3002\u5982\u679c\u53d1\u751f\u8fd9\u79cd\u60c5\u51b5\uff0c\u65e0\u8bba\u4f60\u5728\u54ea\u91cc\uff0c\u5982\u679c\u6709\u4eba\u5165\u4fb5\u4f60\uff0c\u4f60\u5fc5\u987b\u53cd\u51fb\uff0c\u5426\u5219\u4f60\u5c31\u4f1a\u6b7b\u3002\u4f60\u53ef\u80fd\u4e5f\u4f1a\u5728\u6218\u6597\u4e2d\u6b7b\u53bb\uff0c\u6240\u4ee5\u4e3a\u4ec0\u4e48\u4e0d\u53cd\u51fb\u5462?\u201d\n\nh\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1547105294366359553",
#         "text": "RT @yhgarc: \u0e25\u0e2d\u0e22\u0e21\u0e32\n\n#bbrightvc \n#TBMonogramxBrightWin https://t.co/dr542L7uHo"
#     }
# }
# {
#     "data": {
#         "id": "1547105294362284033",
#         "text": "RT @ltslexi2legit: hey gamers can we be more than friends? \ud83d\udda4 https://t.co/3Esh1zRyFa"
#     }
# }
# {
#     "data": {
#         "id": "1547105294370500609",
#         "text": "RT @anyizhou2326: \u0e08\u0e32\u0e01\u0e27\u0e31\u0e19\u0e19\u0e31\u0e49\u0e19                                     \u0e2a\u0e39\u0e48\u0e27\u0e31\u0e19\u0e19\u0e35\u0e49 https://t.co/1sy1YyjQH1"
#     }
# }
# {
#     "data": {
#         "id": "1547105294387380225",
#         "text": "RT @YALNIZIZ_2022: @evkaf @hasanturetr @hkemalkurt \n@vedatbilgn @fuatoktay @suleymansoylu @hmbakanligi @tcbestepe @csgbakanligi @numankurtu\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1547105294387404800",
#         "text": "@sansmemoire https://t.co/mzCK845OvT"
#     }
# }
# {
#     "data": {
#         "id": "1547105294353715200",
#         "text": "RT @AntoeJoy: \u0905\u092c #SSCGD2018 CAPF \u0915\u093e \u092c\u093e\u0924 \u0938\u0941\u0928 \u0932\u0947 \u0938\u0930\u0915\u093e\u0930 \n \u0928\u093f\u092f\u0941\u0915\u094d\u0924\u093f \u092a\u0924\u094d\u0930 \u0928 \u092e\u093f\u0932\u0928\u0947 \u0915\u0947 \u0915\u093e\u0930\u0923 \u0939\u092e \u0928\u093f\u0915\u0932\u0947 \u0939\u0948 \u0905\u092a\u0928\u0940 \u0935\u0930\u094d\u0926\u0940 \u0915\u0947 \u0916\u093e\u0924\u093f\u0930 #\u0928\u093e\u0917\u092a\u0941\u0930_\u0938\u0947_\u0926\u093f\u0932\u094d\u0932\u0940_\u092a\u0948\u0926\u0932\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1547105294362230784",
#         "text": "RT @SBENAT92: \u00c0 tous ces abrutis qui ne comprennent rien \u00e0 l'\u00e9conomie. Soutien total au Pr\u00e9sident #Macron."
#     }
# }
# {
#     "data": {
#         "id": "1547105294362152961",
#         "text": "@soperlonely https://t.co/ZefdwYXXR6"
#     }
# }
# {
#     "data": {
#         "id": "1547105294362492928",
#         "text": "@shimoshun4 \u5929\u624d"
#     }
# }
# {
#     "data": {
#         "id": "1547105294383210497",
#         "text": "RT @amalgam8NFT: Big shout-out to @ottothepoolboy for taking over Tankies!\n\nI've long since written this off as a bad investment. Right now\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1547105294358122501",
#         "text": "RT @turkeymoments81: The moment of hatching of chicks #shorts #shortvideos #animalshorts https://t.co/oMRNNHamLS @YouTube"
#     }
# }
# {
#     "data": {
#         "id": "1547105294391468033",
#         "text": "RT @phanaqvv: \u0e40\u0e01\u0e34\u0e19\u0e04\u0e33\u0e27\u0e48\u0e32\u0e44\u0e2b\u0e27\u0e49\u0e22\u0e48\u0e2d\u0e44\u0e1b\u0e21\u0e32\u0e01 \u0e19\u0e35\u0e48\u0e21\u0e31\u0e19\u0e44\u0e2b\u0e27\u0e49\u0e19\u0e31\u0e48\u0e07\u0e22\u0e2d\u0e07 555555555555555555555555555 https://t.co/IMnrctm9lO"
#     }
# }
# {
#     "data": {
#         "id": "1547105294383464448",
#         "text": "RT @Fox1mu: \ud83c\udf81LARGE $SOL GIVEAWAY \ud83c\udf81\n\n10 ~ $SOL \u2022 350 $USD \n\nRT &amp; Follow @Fox1mu \n\n\u23f0End 24 HR\u23f0 #Solana #SOL #SolanaNFTs #SolGiveaway"
#     }
# }
# {
#     "data": {
#         "id": "1547105294387331072",
#         "text": "@kido_xxz \u3048\u301c\u2661\u3081\u3063\u3061\u3083\u5b09\u3057\u3044!!\ud83e\udd7a\n\u4eba\u751f\u521d\u306e\u30cd\u30a4\u30eb\u30b5\u30ed\u30f3\u884c\u3063\u3066\u304d\u305f\u2755"
#     }
# }
# {
#     "data": {
#         "id": "1547105294374735872",
#         "text": "RT @sunnewstamil: #CinemaUpdate | \u0ba4\u0bbf\u0bb0\u0bc1\u0b9a\u0bcd\u0b9a\u0bbf\u0bb1\u0bcd\u0bb1\u0bae\u0bcd\u0baa\u0bb2\u0bae\u0bcd 2\u0bb5\u0ba4\u0bc1 Single \u0b85\u0baa\u0bcd\u0b9f\u0bc7\u0b9f\u0bcd\n\n#Sunnews | #Thiruchitrambalam | #MeghamKarukkatha | #Dhanush | @dh\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1547105294387486720",
#         "text": "#Alitocachondo https://t.co/mMTePXVMwM"
#     }
# }
# {
#     "data": {
#         "id": "1547105294370500608",
#         "text": "RT @pjmfilmz: jimin's cute habit of missing loop(s) with his belt is so endearing \ud83d\ude2d https://t.co/One0RyZJZf"
#     }
# }
# {
#     "data": {
#         "id": "1547105294353928193",
#         "text": "\u7d39\u4ecb\u30b3\u30fc\u30c9\u2935\ufe0f\u3092\u5165\u308c\u308b\u3068\u30015%\u5272\u5f15\u306b\u306a\u308a\u307e\u3059\niHerb \u30af\u30fc\u30dd\u30f3\u30b3\u30fc\u30c9\uff08\u30d7\u30ed\u30e2\u30b3\u30fc\u30c9).  \u30a2\u30a4\u30cf\u30fc\u30d6\n\u30ea\u30d4\u30fc\u30bf\u30fc 5%\u5272\u5f15\n\u521d\u56de $5\u5272\u5f15\n\n\u2764\ufe0f\u3010 DJY9122 \u3011\u2764\ufe0f\n\n\u30d7\u30ed\u30c6\u30a4\u30f3\u3001\n\u6297\u9178\u5316\u30b5\u30d7\u30ea\u30e1\u30f3\u30c8\u3068\u5316\u7ca7\u54c1\u3001\n \u3001\u30bf\u30f3\u30d1\u30af\u8cea\u3068\u98df\u4e8b\u3001FayCCP&gt;Bcaa\u3001\n\u7b4b\u8089\u30c8\u30ec\u30fc\u30cb\u30f3\u30b0\u306a\u3069\u3002\u306b\u304a\u3059\u3059\u3081/FayCCP"
#     }
# }
# {
#     "data": {
#         "id": "1547105294370873345",
#         "text": "\u3010\u30c9\u30e9\u30af\u30a87 BGM\u3011\u9b54\u5854\u306e\u97ff\u304d1.2.3.4.5 https://t.co/Nhpq7QoEPQ \n\n\u30ea\u30fc\u30c8\u30eb\u30fc\u30c9\u306e\u6642\u9593\u505c\u6b62\u6642\u306e\u6642\u8a08\u5854BGM\u306f\n\u5b50\u4f9b\u306e\u9803\u306e\u30c8\u30e9\u30a6\u30de(\u203a\u00b4\u03c9`\u2039 )"
#     }
# }
# {
#     "data": {
#         "id": "1547105294357909506",
#         "text": "RT @ebikaniaquarium: \u4ef2\u9593\u5165\u308a\u301c\uff01\uff01\n\n\u3059\u3053\u3076\u308b\u7acb\u6d3e\u3067\u7dba\u9e97\u306a\u30a2\u30df\u30e1\u30ce\u30b3\u30ae\u30ea\u30ac\u30b6\u30df\u3055\u3093\u3092\u5bc4\u8d08\u3044\u305f\u3060\u304d\u307e\u3057\u305f\u3088\u301c\uff01\n\n\u753a\u5185\u3067\u6355\u7372\u3055\u308c\u305f\u3082\u306e\u3067\u3001\u3044\u3044\u30b5\u30a4\u30ba\u306a\u306e\u3067\u3001\u305c\u3072\uff01\u3068\u3044\u3046\u3053\u3068\u3067\u3057\u305f\n\n\u3042\u308a\u304c\u3068\u3046\u3054\u3056\u3044\u307e\u3059\uff01\n\u5927\u5207\u306b\u98fc\u80b2\u3057\u307e\u3059\uff01\n\n\u3061\u3068\u7370\u731b\u3059\u304e\u308b\u306e\u3067\u3001\u98fc\u80b2\u8a2d\u5099\u7834\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1547105294353715201",
#         "text": "RT @j0_0124: \u2614\ufe0f #\uc7bc\uc820 #minno https://t.co/ioOzOEFAS2"
#     }
# }
# {
#     "data": {
#         "id": "1547105294387277824",
#         "text": "RT @nijisanji_app: \u3010VOLTACTION \u672c\u65e5\u30c7\u30d3\u30e5\u30fc\uff01\ud83c\udf89\u3011\n\n\u65b0\u898f\u30c7\u30d3\u30e5\u30fc\u30e6\u30cb\u30c3\u30c8\u300cVOLTACTION\u300d\u3068\u3057\u3066\u3001\u65b0\u305f\u306b4\u540d\u304c\u306b\u3058\u3055\u3093\u3058\u30e9\u30a4\u30d0\u30fc\u3068\u3057\u3066\u30c7\u30d3\u30e5\u30fc\uff01\n\u672c\u65e57/13(\u6c34)\u3088\u308a\u6d3b\u52d5\u958b\u59cb\u3044\u305f\u3057\u307e\u3059\uff01\n\n\u8a73\u7d30\u306f\u3053\u3061\u3089\uff01\u25bd\nhttps://t.co/fd\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1547105294370500611",
#         "text": "RT @AreumPromotes: $10 || 140K IDR GIVEAWAY \u2014 60 MINS \ud83e\uddda\n\nRT like &amp; follow @vousmeynvoyez"
#     }
# }
# {
#     "data": {
#         "id": "1547105294375092224",
#         "text": "RT @Allbrightvc: \u0e40\u0e14\u0e34\u0e19\u0e17\u0e32\u0e07\u0e44\u0e1b\u0e2a\u0e34\u0e07\u0e04\u0e42\u0e1b\u0e23\u0e4c\u0e42\u0e14\u0e22\u0e2a\u0e27\u0e31\u0e2a\u0e14\u0e34\u0e20\u0e32\u0e1e\u0e17\u0e31\u0e49\u0e07\u0e04\u0e39\u0e48\u0e19\u0e30\u0e04\u0e30\ud83d\udeeb\ud83c\uddf8\ud83c\uddec\n\n#TBMonogramxBrightWin\n#bbrightvc https://t.co/JOrliLUbZK"
#     }
# }
# {
#     "data": {
#         "id": "1547105294383300608",
#         "text": "RT @Naija_PR: \u2018Squid Game\u2019 has made history as the first Non-English drama series nominee at 2022 Emmys"
#     }
# }
# {
#     "data": {
#         "id": "1547105294370619394",
#         "text": "RT @LeilaniDowding: Wondered why Old Billy boy is here.  Well the farming expert is here  to save British farming with vaccines and genetic\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1547105294374674433",
#         "text": "RT @AsimRiazworld: 1 RT = 1 wish to @imrealasim \n\n#HappyBirthdayAsimRiaz"
#     }
# }
# {
#     "data": {
#         "id": "1547105294379274240",
#         "text": "@suna_uuu \u304a\u8fd1\u3065\u304d\u306e\u5370\u306b\u30ab\u30e1\u30e9\u306b\u9332\u753b\u3057\u305fAV\u52d5\u753b\u304c\u3042\u308b\u3093\u3067\u3059\u3051\u3069\u898b\u307e\u3059\u304b?"
#     }
# }
# {
#     "data": {
#         "id": "1547105294378999814",
#         "text": "RT @WADIAMONDBK: \ud83e\udd14\ud83e\udd14\ud83e\udd14\ud83e\udd28\ud83e\udd2c\u2620"
#     }
# }
# {
#     "data": {
#         "id": "1547105294357958656",
#         "text": "RT @lglaw7: \uc77c\ubcf8\uc774 \ud5c8\ub77d\ud574\uc57c \ub418\ub294\uc77c \uc774\ub7f0\uac70\uc784?"
#     }
# }
# {
#     "data": {
#         "id": "1547105294378999813",
#         "text": "RT @Daphanezz: I Love His \"Pok\u00e9\"Mon \ud83c\udf46\ud83d\udc9b\n\n@Daphanezz \nhttps://t.co/JORmlewaAF \n\nhttps://t.co/r0J1YVGMVE https://t.co/ijMjstZztD"
#     }
# }
# {
#     "data": {
#         "id": "1547105294391644160",
#         "text": "RT @_antonio256: #PraisePropertyConsultsUganda\n\nPLOTS ON SALE:\n\nIn Namugongo_Sonde, few metres from the main road.\n\nSuitable for apartments\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1547105294362238976",
#         "text": "Maybe her little bf that lives in the same town as her that won\u2019t go see her made  her feel a little better \ud83d\ude02\ud83d\ude02\ud83d\ude02"
#     }
# }
# {
#     "data": {
#         "id": "1547105298564861952",
#         "text": "RT @YooJu_O_O: \uc5b4\uc81c \ub370\uac00\ud558\ub2e4\uac00 \ub354\uc6cc\uc11c \uc720\ub85c\ud30c \uac10 (\ubb50\uc784?) https://t.co/I4Td8790iF"
#     }
# }
# {
#     "data": {
#         "id": "1547105298581753856",
#         "text": "RT @thewingsofbts: @btsgaveme2wings @BTS_twt \ud83d\udcf9 | Video promocional de Jung Hoseok para W Korea!\n#MTVMIAWHITGLOBALMYUNIVERSE #PremiosMTVMiaw\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1547105298552238080",
#         "text": "RT @jonlis1: To whomever it may concern: after the Farah story, please don\u2019t start saying \u2018think how many other future heroes we might be d\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1547105298585886720",
#         "text": "RT @Kimstaxxx: Let\u2019s do it with no hands \ud83d\udc45\ud83d\udca6\ud83d\udca6\ud83d\udca6 Full video below \ud83d\udc8b https://t.co/sNu7VqlYyh"
#     }
# }
# {
#     "data": {
#         "id": "1547105298560987136",
#         "text": "\u3010\u30d5\u30ed\u30c1\u30e37\u6708\u4e88\u5b9a\u3011\n13\u65e5\uff08\u6c34\uff09\u901a\u5e38\u55b6\u696d\n14\u65e5\uff08\u6728\uff09\u901a\u5e38\u55b6\u696d\n15\u65e5\uff08\u91d1\uff09\u901a\u5e38\u55b6\u696d\n16\u65e5\uff08\u571f\uff09\u571f\u65e5\u55b6\u696d\n17\u65e5\uff08\u65e5\uff09\u571f\u65e5\u55b6\u696d\n18\u65e5\uff08\u795d\uff09\u571f\u65e5\u55b6\u696d\n19\u65e5\uff08\u706b\uff09\u901a\u5e38\u55b6\u696d\n20\u65e5\uff08\u6c34\uff09\u901a\u5e38\u55b6\u696d\n21\u65e5\uff08\u6728\uff09\u901a\u5e38\u55b6\u696d\n\u203b\u6765\u9031\u3069\u3053\u304b\u3067\u4f11\u307f\u307e\u3059\n\n\u25c6\u901a\u5e38\u55b6\u696d 18\u6642\uff5e0\u6642\n\u25c6\u571f\u65e5\u55b6\u696d 13\u6642\uff5e0\u6642\n\n#26chart https://t.co/aXZfwf1Yt5"
#     }
# }
# {
#     "data": {
#         "id": "1547105298560585729",
#         "text": "RT @kr_now: #\ub3d9\ud574 #\uc740\ud601 \uacfc \ud568\uaed8\ud558\ub294 #\ub338\ub2c8\uc1fc\n\uc774\uac8c #\uba38\uc120129 \uc624\ub298 PM7\uc2dc!\n#\uc601\ud0c1 \uacfc \ud568\uaed8 \uc0dd\ubc29\uc1a1\uc73c\ub85c \uc9c4\ud589\ud560 \uc608\uc815!!!\n\ub178\ub798\ub3c4 \ubd80\ub974\uace0 \ucda4\ub3c4 \ucd94\uace0 \uc18c\ud1b5\ub3c4 \ud558\uace0!\n7/13 (\uc218) PM7\uc2dc \uc601\ud0c1\uc774 \ub2e4\ub4e4 \uae30\ub2e4\ub9ac\uace0 \uc788\ub338\ub2c8\ud83d\udc99\n#navernow\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1547105298556809217",
#         "text": "RT @_opywpyy_: Wow\ud83e\udd29\ud83e\udd29\ud83e\udd29\ud83e\udd29\ncr. bester_besecret \n\n#TBMonogramxBrightWin \n#\u0e44\u0e1a\u0e23\u0e4c\u0e17\u0e27\u0e34\u0e19 #bbrightvc #winmetawin https://t.co/ilyInTks9H"
#     }
# }
# {
#     "data": {
#         "id": "1547105298585751552",
#         "text": "RT @mecchiboo: AHHH I LOVE THEM SO MUCH \ud83d\ude2d https://t.co/KoTiO41fSM"
#     }
# }
# {
#     "data": {
#         "id": "1547105298552213504",
#         "text": "@miyumiyuFGOAC @Light34083838 @arimi_FGO \u30c0\u30f4\u30a3\u30f3\u30c1\u4f7f\u3046\u304b\u3089\u3044\u3044\u3088\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1547105298585894912",
#         "text": "RT @GuillaumeBarucq: L\u2019heure est grave. \n\nEn faisant voter un pass sanitaire aux fronti\u00e8res, certains croient encore en la politique Z\u00e9ro C\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1547105298552340481",
#         "text": "RT @pieceofdarkart: \u064a\u0645\u0643\u0646 \u062e\u064a\u0627\u0644\u064a \u0648\u062f\u0627\u0646\u064a \u0644\u062f\u0646\u064a\u0627 \u0627\u0648 \u0644\u0639\u0627\u0644\u0645 \u062a\u0627\u0646\u064a"
#     }
# }
# {
#     "data": {
#         "id": "1547105298548228097",
#         "text": "RT @LCP: Coup de th\u00e9\u00e2tre dans l'h\u00e9micycle ! L'article 2, qui permettait d'instaurer jusqu'en janvier un passe sanitaire aux fronti\u00e8res et e\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1547105298556788742",
#         "text": "in a video game\u314b\u314b\u314b\u314b\u314b\u314b\u314b\u314b\u314b\u314b\u314b\u314b\u314b"
#     }
# }
# {
#     "data": {
#         "id": "1547105298586152960",
#         "text": "@toraji98 \u306a\u3093\u3082\u601d\u3063\u3066\u306a\u3044\u304b\u3089\u3069\u3046\u3067\u3082\u3044\u3044\u3051\u3069\u3055\n\u7d61\u307e\u306a\u3044\u304b\u3089\u7d61\u307f\u306b\u6765\u305f\u3060\u3051\u306a\u3093\u3088\u306a\u270c\ufe0fWWW"
#     }
# }
# {
#     "data": {
#         "id": "1547105298581708800",
#         "text": "RT @18TIKTOK2: \u2663\ufe0f\u2663\ufe0f https://t.co/TLIas0R4sZ"
#     }
# }
# {
#     "data": {
#         "id": "1547105298548412416",
#         "text": "RT @metacutee: karna aku happy bgt hari ini, aku mau bagi spay buat 3 org , nominal nya rahasia.\n\nrt aja.\nend ntr sore . https://t.co/CJ2Lf\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1547105298581790720",
#         "text": "RT @aliyahInterlude: no lie if covid never happened i would be a completely different person\ud83d\ude2d"
#     }
# }
# {
#     "data": {
#         "id": "1547105298568990720",
#         "text": "RT @WaktaverSSe: \ubc84\uc2a4\uc5d0\uc62c\ub77c\ud0c0\ub098\ub294\ub098\uc9c0\ub9c9\ud788\ub9d0\ud588\ub2e4..\n\"28\uba85\uc774\uc694.\"\n\uae30\uc0ac\uc544\uc800\uc528\ub294\uc5b4\ub9ac\ub465\uc808\ud55c\ud45c\uc815\uc744\uc9c0\uc5c8\ub2e4\n\ub098\ub294\uc6c3\uc73c\uba70\ub9d0\ud588\ub2e4\n\"\uc81c\uac00\uc2b4\uc18d\uc5d0\uc774\uc138\ub3cc\uc774\ub77c\ub2946\uba85\uacfc\uace0\uba64\uc774\ub77c\ub29421\uba85\uc774\uc0b4\uace0\uc788\uac70\ub4e0\uc694.\"\n\uadf8\ub7ec\uc790\uae30\uc0ac\uc544\uc800\uc528\ub294\ub450\uba85\ubd84\uc694\uae08\ub9cc\ucc0d\uc73c\uba70\ub9d0\ud588\ub2e4\n\"\ubc14\ubcf4\uac19\uc73c\ub2c8.\uc641\ud0c0\ubc84\uc2a4\ub294\u300c\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1547105298560782337",
#         "text": "RT @docrussjackson: How close are we to the bit where Boris Johnson encourages delusional Tory supporting right-wing conspiracy theorist ex\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1547105298556473344",
#         "text": "RT @tongthk: \u0e15\u0e2d\u0e19\u0e40\u0e14\u0e47\u0e01\u0e46 \u0e40\u0e04\u0e22\u0e0a\u0e2d\u0e1a\u0e21\u0e30\u0e40\u0e02\u0e37\u0e2d\u0e40\u0e17\u0e28\u0e21\u0e32\u0e01 \u0e01\u0e34\u0e19\u0e14\u0e34\u0e1a\u0e46\u0e08\u0e34\u0e49\u0e21\u0e40\u0e01\u0e25\u0e37\u0e2d\u0e14\u0e49\u0e27\u0e22\u0e0b\u0e49\u0e33 \u0e41\u0e15\u0e48\u0e40\u0e01\u0e25\u0e35\u0e22\u0e14\u0e1c\u0e31\u0e01\u0e43\u0e1a\u0e40\u0e02\u0e35\u0e22\u0e27\u0e2a\u0e38\u0e14\u0e46 \u0e41\u0e15\u0e48\u0e1e\u0e2d\u0e42\u0e15\u0e21\u0e32 \u0e0b\u0e36\u0e48\u0e07\u0e01\u0e47\u0e08\u0e33\u0e44\u0e21\u0e48\u0e44\u0e14\u0e49\u0e41\u0e25\u0e49\u0e27\u0e27\u0e48\u0e32\u0e15\u0e2d\u0e19\u0e44\u0e2b\u0e19\u0e17\u0e35\u0e48\u0e40\u0e23\u0e34\u0e48\u0e21\u0e40\u0e01\u0e25\u0e35\u0e22\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1547105298577788928",
#         "text": "RT @nokkusuart: #\u539f\u795e #Genshinlmpact https://t.co/2mSi6LfqJV"
#     }
# }
# {
#     "data": {
#         "id": "1547105298586161157",
#         "text": "RT @twtCats: Love kedi https://t.co/vrYz0g1wcw"
#     }
# }
# {
#     "data": {
#         "id": "1547105298548019200",
#         "text": "RT @inoueart: https://t.co/0jsQ4ZGAVK"
#     }
# }
# {
#     "data": {
#         "id": "1547105298577592320",
#         "text": "@wixxynashy You don't deserve a fone. Munotirambisa kunze uko https://t.co/9b99PhcAvw"
#     }
# }
# {
#     "data": {
#         "id": "1547105298560606208",
#         "text": "@moonareas puyeng"
#     }
# }
# {
#     "data": {
#         "id": "1547105298548154374",
#         "text": "RT @EricLagadec: C'est le d\u00e9but d'une nouvelle \u00e8re pour l'astrophysique et notre compr\u00e9hension de l'Univers. Le t\u00e9lescope spatial James Web\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1547105298560667648",
#         "text": "RT @TheMonstervers: Wahhh @GodzillaMovie and South Hero  @tarak9999 like #Godzilla \n\n#TheMonsterverseContinues \n#GodzillaVsKong https://t.c\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1547105298581577728",
#         "text": "RT @sachin_rt: I have been lucky to have not 1 but 3 Gurus - my father, Achrekar Sir &amp; my brother Ajit. They taught me not just cricket, bu\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1547105298564923393",
#         "text": "Never mind on that sleep I had scheduled for tonight. I can sleep when the kids are grown. \n\ud83d\udc67+\ud83e\udd2e=\u23f0 https://t.co/KMQxErRBr4"
#     }
# }
# {
#     "data": {
#         "id": "1547105298569109505",
#         "text": "\u0627\u0644\u0644\u0647\u0645 \u0628\u0627\u0639\u062f \u0628\u064a\u0646\u064a \u0648\u0628\u064a\u0646 \u0627\u0644\u0645\u0639\u0627\u0635\u064a \u0648\u062b\u0628\u062a\u0646\u064a \u0648\u062c\u0639\u0644 \u0635\u0641\u062d\u062a\u064a \u0628\u064a\u0636\u0627\u0621 \u064a\u0648\u0645 \u0644\u0642\u0627\u0626\u0643 \u2665\ufe0f."
#     }
# }
# {
#     "data": {
#         "id": "1547105298569375744",
#         "text": "RT @HamuHamu150: \ud83d\udc39\u30d7\u30ec\u30bc\u30f3\u30c8\u4f01\u753b\ud83d\udc39\n\n\uff0f\n     \u9078\u3079\u308b1,000\u5186\u00d7 1\u540d\u69d8\ud83c\udf81\n\uff3c\n\n\u25ab\ufe0e\u5fdc\u52df\u65b9\u6cd5\n\u2611\ufe0e@HamuHamu1500 Follow\n\n\u2611\ufe0e\u3053\u306e\u6295\u7a3f\u306eRT\u267b\ufe0f\n\n\u300a\u7de0\u5207\u300b7/13  22:00\u3006 https://t.co/RUQetYbrCB"
#     }
# }
# {
#     "data": {
#         "id": "1547105298577440768",
#         "text": "RT @TMIndy_: \u0e1f\u0e34\u0e19\u0e19\u0e32\u0e40\u0e25\u0e48\u0e1e\u0e2d\u0e44\u0e2b\u0e21\u0e08\u0e4a\u0e30\u0e40\u0e1e\u0e19\u0e2a\u0e34\u0e49\u0e19 https://t.co/aujlGUBdsz"
#     }
# }
# {
#     "data": {
#         "id": "1547105298565177344",
#         "text": "RT @4kage_: \u6587\u5316\u653e\u9001\u306b\u5411\u304b\u3046\u9053\u3067\u5c0f\u91ce\u5927\u8f14\u306e\u80cc\u4e2d\u3092\u898b\u3066\u300c\u30d6\u30e9\u30d6\u30e9\u6b69\u3044\u3066\u308b\u30d0\u30ab\u304c\u5c45\u3093\u306a\u3041\u300d\u3068\u601d\u3044\u306a\u304c\u3089\u300c\u306a\u3041\u306a\u3041\u304a\u3044\u98ef\u304a\u3054\u3063\u3066\u304f\u308c\u3088\u306a\u3041\u306a\u3041\u304a\u3044\u98ef\u98df\u304a\u3046\u305c\u300d\u3068\u5f8c\u308d\u304b\u3089\u58f0\u3092\u304b\u3051\u305f\u91ce\u751f\u306e\u795e\u8c37\u6d69\u53f2\u306e\u8a71\u3057\u3057\u307e\u3059\u304b\uff1f"
#     }
# }
# {
#     "data": {
#         "id": "1547105298552221696",
#         "text": "RT @RuiThroatfucker: \u6253\u5f00\u8033\u673a\uff0c\u5c3d\u60c5\u8046\u542c\u9f9f\u5934\u5728\u98df\u9053\u91cc\u6469\u64e6\u7684\u58f0\u97f3@Dpthroater1 https://t.co/RIGVRPXHpE"
#     }
# }
# {
#     "data": {
#         "id": "1547105298565021698",
#         "text": "RT @Hazan82284115: Tez elde edilen ba\u015far\u0131, insan\u0131 karars\u0131z   #akcaysex #akcay  ve maceraperest yapar. https://t.co/YQLkxk4hX8"
#     }
# }
# {
#     "data": {
#         "id": "1547105302754955264",
# ...
#     }
# }
# {
#     "data": {
#         "id": "1547105336317906945",
#         "text": "@_pnaarr TorpilinAd\u0131 NisaB\u00f6l\u00fckba\u015f\u0131"
#     }
# }
# {
#     "data": {
#         "id": "1547105336334716928",
#         "text": "RT @NAGarachtchenko: Happy Portfolio Day!!\nI'm Nastia and I just finished my certification in Environmental Art at Emile Cohl Atelier! \nI'm\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1547105336309563392",
#         "text": "\ud83c\udf4e\ud83d\ude04\ud83d\udc96\ud83d\udc30 https://t.co/gz0b2zNhk0"
#     }
# }
# {
#     "data": {
#         "id": "1547105336313757696",
#         "text": "@Alahli_w1 \u0627\u0647\u0644\u0627 \u0648\u0633\u0647\u0644\u0627 \u0628\u064a\u0643\u064a \u062d\u0628\u064a\u0628\u062a\u064a \ud83d\ude18"
#     }
# }
# {
#     "data": {
#         "id": "1547105336330444801",
#         "text": "@sieunsmooch cryinf ty \ud83e\udd7a\ud83e\udd7a\ud83e\udd7a"
#     }
# }
# {
#     "data": {
#         "id": "1547105336334503937",
#         "text": "RT @javroar: at this point ion even know if im breathing correctIy https://t.co/RTSHlNbT8P"
#     }
# }
# {
#     "data": {
#         "id": "1547105336309567488",
#         "text": "Hunter Biden weighing cr4ck on a scale\u2026 dude was a total crack head\nhttps://t.co/2RkHGkJjmH"
#     }
# }
# {
#     "data": {
#         "id": "1547105336309723136",
#         "text": "RT @_VERMICULAR_: \uff3c7/14\u5148\u884c\u4e88\u7d04\u958b\u59cb\u30fb7/28\u767a\u58f2\uff01\uff0f\n\uff03\u30d0\u30fc\u30df\u30ad\u30e5\u30e9 \u304b\u3089\u30d7\u30ec\u30df\u30a2\u30e0\u306a\u65b0\u88fd\u54c1\u304c\u767b\u5834\uff01\uff01\n\n\u65b0\u88fd\u54c1\u306f\u3001\n1\u20e3 \uff03\u30d7\u30ec\u30df\u30a2\u30e0\u306a\u934b \n2\u20e3 \uff03\u30d7\u30ec\u30df\u30a2\u30e0\u306a\u30e9\u30a4\u30b9\u30dd\u30c3\u30c8 \n3\u20e3 \uff03\u30d7\u30ec\u30df\u30a2\u30e0\u306a\u30d5\u30e9\u30a4\u30d1\u30f3\n\u306e\u3069\u308c\u3067\u3057\u3087\u3046\uff1f\n\n\uff8c\uff6b\uff9b\uff70\uff06\u6b63\u89e3\u3060\u3068\u601d\u3046\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1547105336305192962",
#         "text": "\u697d\u59291\u4f4d\u3010\u6700\u59276000\u5186\u30af\u30fc\u30dd\u30f3\u914d\u5e03\u4e2d\u3011\u301010\u500dP\u9084\u5143\u4e2d\u3011HUAWEI Band 7 \u30b9\u30de\u30fc\u30c8\u30a6\u30a9\u30c3\u30c1 1.47\u30a4\u30f3\u30c1\u8584\u578b\u5927\u753b\u9762 2\u9031\u9593\u306e\u30ed\u30f3\u30b0\u30d0\u30c3\u30c6\u30ea\u30fc \u8840\u4e2d\u9178\u7d20\u5e38\u6642\u6e2c\u5b9a \u6025\u901f\u5145\u96fb \u6700\u592796\u7a2e\u985e\u306e\u30ef\u30fc\u30af\u30a2\u30a6\u30c8\u30e2\u30fc\u30c9 641\n\n\u697d\u5929 \u304a\u3059\u3059\u3081\nhttps://t.co/BMRXoBzHO0"
#     }
# }
# {
#     "data": {
#         "id": "1547105336322129922",
#         "text": "G\u00fcnayd\u0131nlar #b\u0131st100 endeksi g\u00fcne hafif sat\u0131c\u0131l\u0131 bir a\u00e7\u0131l\u0131\u015fla ba\u015flamas\u0131 bekleniyor. 1 avro #viop #usdtry #borsa"
#     }
# }
# {
#     "data": {
#         "id": "1547105336309743618",
#         "text": "gusto ko na mag myday livenation anona?"
#     }
# }
# {
#     "data": {
#         "id": "1547105336322150400",
#         "text": "@NeoUnrealist I'm to liberate Saudi Arabia"
#     }
# }
# {
#     "data": {
#         "id": "1547105336296738816",
#         "text": "@ruladetihaiiii @tejrannnn89 @EeshaDas5 Nahiii\ud83d\ude0c"
#     }
# }
# {
#     "data": {
#         "id": "1547105336326524928",
#         "text": "@kazoo0509 \u30dd\u30fc\u30f3\u3068\u3044\u3046\u30bf\u30ac\u304c\u306f\u305a\u308c\u305f\u97f3\u3068\u3001\u3073\u3087\u3046\u3068\u3044\u3046\u30ed\u30fc\u30ab\u30eb\u5929\u72d7\u306e\u3042\u306e\u639b\u3051\u58f0\u304c\u3001\u4eca\u5bb5\u306e\u79c1\u306e\u5922\u306e\u4e2d\u3067\u5927\u66b4\u308c\u3057\u305d\u3046\ud83e\udd23\n\u5b89\u5b9a\u306e\u30dd\u30fc\u30f3\u3001\u3055\u3059\u304c\u3067\u3059\u306a\u3041\u3002"
#     }
# }
# {
#     "data": {
#         "id": "1547105336317792258",
#         "text": "RT @thaipost: \u0e40\u0e2b\u0e22\u0e37\u0e48\u0e2d\u0e2a\u0e32\u0e27 4 \u0e23\u0e32\u0e22\u0e41\u0e08\u0e49\u0e07\u0e08\u0e31\u0e1a '\u0e2a.\u0e01.\u0e01\u0e49\u0e32\u0e27\u0e44\u0e01\u0e25' \u0e25\u0e27\u0e19\u0e25\u0e32\u0e21\u0e17\u0e35\u0e48\u0e04\u0e2d\u0e19\u0e42\u0e14\u0e2f \u0e15\u0e23.\u0e40\u0e15\u0e23\u0e35\u0e22\u0e21\u0e2d\u0e2d\u0e01\u0e2b\u0e21\u0e32\u0e22\u0e40\u0e23\u0e35\u0e22\u0e01 \n\n\u0e01\u0e14\u0e2d\u0e48\u0e32\u0e19 https://t.co/jkJJO2aJGi https://t.co/W2md\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1547105336321986561",
#         "text": "RT @iMac_too: #YankeeNaxal bhai, \u0905\u0902\u0938\u093e\u0930\u0940 \u0905\u0917\u0930 \u0905\u0936\u094b\u0915 \u0938\u094d\u0924\u0902\u092d \u092a\u0930 \u0938\u091c\u0926\u093e \u0915\u0930\u0924\u093e \u0924\u094b \u0939\u093f\u0902\u0926\u0942 \u0932\u094b\u0917 \u091a\u093e\u0939\u0947 \u091c\u094b \u092d\u0940 \u0938\u094b\u091a\u0947 \u0909\u0938\u0915\u0947 \u0916\u0941\u0926\u0915\u0947 \u092d\u093e\u0908 \u0932\u094b\u0917 \u0938\u0930 \u0924\u0928 \u0938\u0947 \u091c\u0941\u0926\u093e \u0915\u0947 \u0928\u093e\u0930\u0947\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1547105340525002752",
#         "text": "@mahidayoh \u30c0\u30e1\u3067\u3059\u3002"
#     }
# }
# {
#     "data": {
#         "id": "1547105336301129729",
#         "text": "@nickson_256 @912CroozeFM @dorothyainemba1 @delyderric @Swagadat @mhercy256 @UgandaWaragi @Guinness_Uganda @Mugibson @marvinkam8 @wizzy_ep #MUSTBash\n#UgandaWaragiBash"
#     }
# }
# {
#     "data": {
#         "id": "1547105336317792256",
#         "text": "M quiero dormir y no despertarme nunca m\u00e1s."
#     }
# }
# {
#     "data": {
#         "id": "1547105336313749505",
#         "text": "RT @jimanfc1306: 220713 | WEVERSE\nBTS ON &amp; OFF TEASER :: SUGA \n\n#BTS #SUGA #YOONGI @BTS_twt https://t.co/ONFwfq5DXZ"
#     }
# }
# {
#     "data": {
#         "id": "1547105340529192960",
#         "text": "\u3048\ud83d\ude33\ud83d\udc95\u304b\u308f\u3044\u3044\n\n\ud83e\udd8a\ud83d\udc99\u3044\u308b\u3068\u601d\u3063\u3066\u306a\u304b\u3063\u305f\u304b\u3089\ud83e\udd7a\u6700\u63a8\u3057\u3068\u4e00\u7dd2\u306b\u304a\u8fce\u3048\u3057\u305f\u3044\u2026 https://t.co/4Xhj2Ec77H"
#     }
# }
# {
#     "data": {
#         "id": "1547105340504035328",
#         "text": "RT @chartdata: j-hope's \"MORE\" rises to #1 on the weekly #HotTrendingSongs chart for the first time. It marks his first #1 hit."
#     }
# }
# {
#     "data": {
#         "id": "1547105340524830720",
#         "text": "@CryptoBarP2P https://t.co/MBNXTovSOs , Presale is coming soon , dev is based and the HC is small , international communities , meme contests and more!\n\n#Soccermoon #BNB #BSCgems #SocecermoonBSCgem #SoccermoonArmy #Memecontest #BSC #Dogecoin #Memecoin"
#     }
# }
# {
#     "data": {
#         "id": "1547105340512157697",
#         "text": "RT @coybarker: Know this is turning right now for your GOOD. It is your turn around time. Philippians 1:19"
#     }
# }
# {
#     "data": {
#         "id": "1547105340491431937",
#         "text": "RT @praewadio: \u0e40\u0e2d\u0e49\u0e32 \u0e1e\u0e35\u0e48\u0e04\u0e34\u0e27\u0e1a\u0e2d\u0e01\u0e1e\u0e35\u0e48\u0e41\u0e08\u0e47\u0e04\u0e22\u0e31\u0e07\u0e21\u0e35\u0e07\u0e32\u0e19\u0e44\u0e17\u0e22\u0e2d\u0e35\u0e01\u0e2b\u0e25\u0e32\u0e22\u0e07\u0e32\u0e19 \u0e04\u0e37\u0e2d\u0e40\u0e2b\u0e47\u0e19\u0e41\u0e15\u0e48\u0e01\u0e32\u0e41\u0e1f \u0e21\u0e35\u0e2d\u0e30\u0e44\u0e23\u0e2d\u0e35\u0e01\u0e01\u0e47\u0e40\u0e09\u0e25\u0e22\u0e2a\u0e34\u0e04\u0e30\ud83e\udee3"
#     }
# }
# {
#     "data": {
#         "id": "1547105340528926720",
#         "text": "RT @mahaesmin: markmin are so unserious like how is it always those two making the dick jokes"
#     }
# }
# {
#     "data": {
#         "id": "1547105340520648704",
#         "text": "RT @TheTNHoller: ICYMI \u2014 @SenatorHagerty spokesman @JuddPDeere (stepped down yesterday) testified today as Deputy Press Sec he told Trump c\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1547105340495646720",
#         "text": "RT @dnaofficial: [\ud83d\udcf8] ELLE Thailand July 2022 Issue \n\n#MarkTuan #Mark \n#\ub9c8\ud06c #\u6bb5\u5b9c\u6069 \n#ELLEJuly2022xMarkTuan \n#imysm #imysm_MarkTuan    \n@marktua\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1547105340491120640",
#         "text": "RT @DaleFourTrump: Pay with just your Palm via Amazon One sign caught seen at a Retail shop. Amazon quote \"Pay by just being you\". \n\nWe're\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1547105340528857089",
#         "text": "@Reshia_14 https://t.co/8ofm5Gtx8z"
#     }
# }
# {
#     "data": {
#         "id": "1547105340524724225",
#         "text": "Damn I\u2019ll really be 23 next year \ud83d\ude2d"
#     }
# }
# {
#     "data": {
#         "id": "1547105340491431936",
#         "text": "RT @Shill_Ronin: $200 | 2.8 JT \u2022 24 hrs \u2022 rt\n\n\u27a1\ufe0f follow @mjmfrance + rt like \ud83d\udccc"
#     }
# }
# {
#     "data": {
#         "id": "1547105340529020928",
#         "text": "#\u0631\u0627\u0642\u062a_\u0644\u064a #\u0635\u0628\u0627\u062d_\u0627\u0644\u062e\u064a\u0631\u1160 https://t.co/6f7XSfpXkO"
#     }
# }
# {
#     "data": {
#         "id": "1547105340495646721",
#         "text": "@riyowai \u304a\u75b2\u308c\u69d8\ud83d\ude0c\ud83d\udc93\ud83c\udf6e https://t.co/fdCVd2KPUe"
#     }
# }
# {
#     "data": {
#         "id": "1547105340512210945",
#         "text": "RT @MarkkoXXX: \ud83c\udd95\ud83c\udfa6 Andrea Novak @novakkoff makes a phenomenal debut on TimTales, together with \"the new\" Caio Veyron. @CaioVeyronXXX has tur\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1547105340529037316",
#         "text": "RT @yoonsgreybeanie: One of my all time favourite Bangtan photos https://t.co/RyqHwkCoSW"
#     }
# }
# {
#     "data": {
#         "id": "1547105340520824832",
#         "text": "RT @m3vhmhr: \u6b63\u793e\u54e1\u3067\u50cd\u3044\u3066\u308b\u306e\u306b\u5168\u7136\u300e\u5065\u5eb7\u7684\u3067\u6587\u5316\u7684\u306a\u6700\u4f4e\u9650\u5ea6\u306e\u751f\u6d3b\u300f\u3067\u304d\u3066\u306a\u3044\u306e\u307b\u3093\u3068\u8349"
#     }
# }
# {
#     "data": {
#         "id": "1547105340512014337",
#         "text": "RT @ipskabra: Your \"Life\" is more important than your \"Likes\". https://t.co/3XNjyirbwJ"
#     }
# }
# {
#     "data": {
#         "id": "1547105340495302656",
#         "text": "Gw gak paham mitaka napa jadiin denji musuh ya"
#     }
# }
# {
#     "data": {
#         "id": "1547105340495253505",
#         "text": "@alcoholic_gt \u5b9f\u969b\u3001\u91d1\u3067\u8cb7\u3048\u308b\u304b\u3089\u3053\u305d\u6efe\u308b\u5922\u3082\u3042\u308b\uff01"
#     }
# }
# {
#     "data": {
#         "id": "1547105340495482881",
#         "text": "RT @214fix: \u2639\ufe0f https://t.co/OQHzpqyANR"
#     }
# }
# {
#     "data": {
#         "id": "1547105340491440128",
#         "text": "To be happy  we must not be too concerned wi.\n\u061f?\n\u0646\u0645\u0634\u06d2\n\n\ud83d\udd39KM11\ud83d\udd39\n\ud83d\udd39KM11\ud83d\udd39\n\ud83d\udd39KM11\ud83d\udd39\n\u0625\u0645\u062a\u0646\u0627\u0646 \u0631\u0634\u0627\u062f \u25e5\u2022\ufedc\u0655\u0648\u0650\u0628\u0648\u0646\u2022 \ufea7\u0655\u0653\u0635\u064d\u0645\u064d\u2022\ufedc\u0655\u0648\u0650\u062f\u0653\u2022"
#     }
# }
# {
#     "data": {
#         "id": "1547105340507820033",
#         "text": "RT @anirbanganguly: India\u2019s banana exports jump 8-fold in 9 yrs; Piyush Goyal says \u2018making world go bananas\u2019:\n\nhttps://t.co/aJtzIJ52KW\n\nvia\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1547105340520480769",
#         "text": "RT @manami_aizono: \u3084\u308b\u305e\uff01\uff01\uff01MR50\u3067\u4f55\u304c\u6765\u3066\u3082\u9a5a\u304b\u306a\u3044\uff01\uff01(\u30d5\u30e9\u30b0)"
#     }
# }
# {
#     "data": {
#         "id": "1547105340499677184",
#         "text": "LOUIS MAMMA MIA https://t.co/SajTWYgSUC"
#     }
# }
# {
#     "data": {
#         "id": "1547105340528795648",
#         "text": "RT @Mythos_HEC: Eighth Trailer + 2000$ #Giveaway\n\n\ud83d\udd25Cerberos\ud83d\udd25\nTotal in collection:  500x\n\n\u25ab\ufe0f250x Common\n\u25ab\ufe0f125x Uncommon\n\u25ab\ufe0f75x Rare\n\u25ab\ufe0f40x Epi\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1547105340516605952",
#         "text": "RT @brfootball: FT: Man Utd 4-0 Liverpool \ud83e\udd2d https://t.co/sNbaXOEPm9"
#     }
# }
# {
#     "data": {
#         "id": "1547105340499841024",
#         "text": "RT @Chai_9700: #DearNothing\nI love and respect every language of our country sir.\n\nI hope everyone can understand this post \ud83d\udcef\n\nHINDI IS NOT\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1547105340520599554",
#         "text": "@_jeivinolaOD Enge peace of mind hahahahah"
#     }
# }
# {
#     "data": {
#         "id": "1547105340512440321",
#         "text": "RT @s_baiitong: \u0e2b\u0e19\u0e49\u0e32\u0e17\u0e25\u0e15\u0e2d\u0e19\u0e19\u0e35\u0e49 .. https://t.co/1ImeVikKSr"
#     }
# }
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [1], in <cell line: 48>()
#      45         timeout += 1
#      48 if __name__ == "__main__":
# ---> 49     main()
#
# Input In [1], in main()
#      42 timeout = 0
#      43 while True:
# ---> 44     connect_to_endpoint(url)
#      45     timeout += 1
#
# Input In [1], in connect_to_endpoint(url)
#      26 response = requests.request("GET", url, auth=bearer_oauth, stream=True)
#      27 print(response.status_code)
# ---> 28 for response_line in response.iter_lines():
#      29     if response_line:
#      30         json_response = json.loads(response_line)
#
# File ~\anaconda3\lib\site-packages\requests\models.py:866, in Response.iter_lines(self, chunk_size, decode_unicode, delimiter)
#     857 """Iterates over the response data, one line at a time.  When
#     858 stream=True is set on the request, this avoids reading the
#     859 content at once into memory for large responses.
#     860
#     861 .. note:: This method is not reentrant safe.
#     862 """
#     864 pending = None
# --> 866 for chunk in self.iter_content(
#     867     chunk_size=chunk_size, decode_unicode=decode_unicode
#     868 ):
#     870     if pending is not None:
#     871         chunk = pending + chunk
#
# File ~\anaconda3\lib\site-packages\requests\models.py:816, in Response.iter_content.<locals>.generate()
#     814 if hasattr(self.raw, "stream"):
#     815     try:
# --> 816         for chunk in self.raw.stream(chunk_size, decode_content=True):
#     817             yield chunk
#     818     except ProtocolError as e:
#
# File ~\anaconda3\lib\site-packages\urllib3\response.py:575, in HTTPResponse.stream(self, amt, decode_content)
#     559 """
#     560 A generator wrapper for the read() method. A call will block until
#     561 ``amt`` bytes have been read from the connection or until the
#    (...)
#     572     'content-encoding' header.
#     573 """
#     574 if self.chunked and self.supports_chunked_reads():
# --> 575     for line in self.read_chunked(amt, decode_content=decode_content):
#     576         yield line
#     577 else:
#
# File ~\anaconda3\lib\site-packages\urllib3\response.py:767, in HTTPResponse.read_chunked(self, amt, decode_content)
#     764     return
#     766 while True:
# --> 767     self._update_chunk_length()
#     768     if self.chunk_left == 0:
#     769         break
#
# File ~\anaconda3\lib\site-packages\urllib3\response.py:697, in HTTPResponse._update_chunk_length(self)
#     695 if self.chunk_left is not None:
#     696     return
# --> 697 line = self._fp.fp.readline()
#     698 line = line.split(b";", 1)[0]
#     699 try:
#
# File ~\anaconda3\lib\socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# File ~\anaconda3\lib\ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1237     if flags != 0:
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#    1243     return super().recv_into(buffer, nbytes, flags)
#
# File ~\anaconda3\lib\ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1097 try:
#    1098     if buffer is not None:
# -> 1099         return self._sslobj.read(len, buffer)
#    1100     else:
#    1101         return self._sslobj.read(len)
#
# KeyboardInterrupt:
